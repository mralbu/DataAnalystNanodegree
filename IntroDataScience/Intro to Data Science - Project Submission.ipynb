# %% [markdown]
# #Intro to Data Science
#    ###Data Analyst Nanodegree

# %% [markdown]
# <br>
# The Intro to Data Science class presented foundational topics in data science, such as data manipulation, statistics and information visualization.
# <br>
# Thoughout the course, a dataset containing information on NYC Subway usage in May 2011 was wrangled and analysed. Hourly subway usage patterns were analyzed for different NYC neighbourhoods. It was also possible to show that people are more likely to take the subway on a rainy day.

# %%
import pandas as pd
import seaborn as sns
import geopandas
from shapely.geometry import Point
import folium
from IPython.display import HTML
from ggplot import *

folium.initialize_notebook()
# Out:
# <link rel="stylesheet" href="http://cdn.leafletjs.com/leaflet-0.7.2/leaflet.css" />
# <style>
#     .leaflet-popup-content {
#         color: black !important;
#     }
#
#     .leaflet-control-zoom-in {
#         text-decoration: none !important;
#     }
#
#     .leaflet-control-zoom-out {
#         text-decoration: none !important;
#     }
# </style>
# <script>
#
#   var folium_event = new CustomEvent(
#     "folium_libs_loaded",
#     {bubbles: true, cancelable: true}
#   );
#
#   var load_folium_charts = function(){
#     window.dispatchEvent(folium_event);
#   };
#
#  var load_folium_libs = function(){
#     console.log('Loading all Folium libraries...')
#     $.getScript("http://cdn.leafletjs.com/leaflet-0.7.2/leaflet.js", function(){
#       $.getScript('https://wrobstory.github.io/leaflet-dvf/leaflet-dvf.markers.min.js', function(){
#           if (window['vg'] === undefined){
#             $.getScript("http://wrobstory.github.io/vega/vega.v1.3.3.js", function(){
#               load_folium_charts();
#           });
#         } else {
#           load_folium_charts();
#         }
#       });
#     });
#   };
#
#  if(typeof define === "function" && define.amd){
#       var load_paths = {
#         paths: {
#           topojson:'http://d3js.org/topojson.v1.min',
#           queue: 'http://d3js.org/queue.v1.min',
#           d3: 'http://d3js.org/d3.v3.min'
#         }
#       };
#       var libs = ['d3', 'queue', 'topojson'];
#       for (var i=0; i < libs.length; i++){
#         lib = libs[i]
#         if (window[lib] !== undefined){
#           delete load_paths.paths[lib]
#         };
#       };
#       if (Object.keys(load_paths.paths).length != 0){
#         require.config(load_paths);
#         require(["queue"], function(queue){
#           window.queue = queue;
#         });
#         require(["d3"], function(d3){
#             console.log('Loading from require.js...')
#             window.d3 = d3;
#             require(["topojson"], function(topojson){
#                 window.topojson = topojson;
#                 load_folium_libs();
#             });
#         });
#       } else {
#         load_folium_libs();
#       }
#
#  }else{
#       console.log('Require.js not found!');
#       throw "Require.js not found!"
#  };
#
# </script>

# %%
df = pd.read_csv('./improved-dataset/turnstile_weather_v2.csv', parse_dates=['datetime'])

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42649 entries, 0 to 42648
# Data columns (total 27 columns):
# UNIT               42649 non-null object
# DATEn              42649 non-null object
# TIMEn              42649 non-null object
# ENTRIESn           42649 non-null int64
# EXITSn             42649 non-null int64
# ENTRIESn_hourly    42649 non-null float64
# EXITSn_hourly      42649 non-null float64
# datetime           42649 non-null datetime64[ns]
# hour               42649 non-null int64
# day_week           42649 non-null int64
# weekday            42649 non-null int64
# station            42649 non-null object
# latitude           42649 non-null float64
# longitude          42649 non-null float64
# conds              42649 non-null object
# fog                42649 non-null int64
# precipi            42649 non-null float64
# pressurei          42649 non-null float64
# rain               42649 non-null int64
# tempi              42649 non-null float64
# wspdi              42649 non-null float64
# meanprecipi        42649 non-null float64
# meanpressurei      42649 non-null float64
# meantempi          42649 non-null float64
# meanwspdi          42649 non-null float64
# weather_lat        42649 non-null float64
# weather_lon        42649 non-null float64
# dtypes: datetime64[ns](1), float64(14), int64(7), object(5)
# memory usage: 9.1+ MB
#    UNIT     DATEn     TIMEn  ENTRIESn   EXITSn  ENTRIESn_hourly  \
# 0  R003  05-01-11  00:00:00   4388333  2911002                0
# 1  R003  05-01-11  04:00:00   4388333  2911002                0
# 2  R003  05-01-11  12:00:00   4388333  2911002                0
# 3  R003  05-01-11  16:00:00   4388333  2911002                0
# 4  R003  05-01-11  20:00:00   4388333  2911002                0
#
#    EXITSn_hourly            datetime  hour  day_week     ...       pressurei  \
# 0              0 2011-05-01 00:00:00     0         6     ...           30.22
# 1              0 2011-05-01 04:00:00     4         6     ...           30.25
# 2              0 2011-05-01 12:00:00    12         6     ...           30.28
# 3              0 2011-05-01 16:00:00    16         6     ...           30.26
# 4              0 2011-05-01 20:00:00    20         6     ...           30.28
#
#   rain  tempi  wspdi meanprecipi  meanpressurei  meantempi  meanwspdi  \
# 0    0   55.9    3.5           0         30.258      55.98       7.86
# 1    0   52.0    3.5           0         30.258      55.98       7.86
# 2    0   62.1    6.9           0         30.258      55.98       7.86
# 3    0   57.9   15.0           0         30.258      55.98       7.86
# 4    0   52.0   10.4           0         30.258      55.98       7.86
#
#    weather_lat  weather_lon
# 0    40.700348   -73.887177
# 1    40.700348   -73.887177
# 2    40.700348   -73.887177
# 3    40.700348   -73.887177
# 4    40.700348   -73.887177
#
# [5 rows x 27 columns]

# %%
df.describe()
# Out:
#            ENTRIESn        EXITSn  ENTRIESn_hourly  EXITSn_hourly  \
# count  4.264900e+04  4.264900e+04     42649.000000   42649.000000
# mean   2.812486e+07  1.986993e+07      1886.589955    1361.487866
# std    3.043607e+07  2.028986e+07      2952.385585    2183.845409
# min    0.000000e+00  0.000000e+00         0.000000       0.000000
# 25%    1.039762e+07  7.613712e+06       274.000000     237.000000
# 50%    1.818389e+07  1.331609e+07       905.000000     664.000000
# 75%    3.263049e+07  2.393771e+07      2255.000000    1537.000000
# max    2.357746e+08  1.493782e+08     32814.000000   34828.000000
#
#                hour      day_week       weekday      latitude     longitude  \
# count  42649.000000  42649.000000  42649.000000  42649.000000  42649.000000
# mean      10.046754      2.905719      0.714436     40.724647    -73.940364
# std        6.938928      2.079231      0.451688      0.071650      0.059713
# min        0.000000      0.000000      0.000000     40.576152    -74.073622
# 25%        4.000000      1.000000      0.000000     40.677107    -73.987342
# 50%       12.000000      3.000000      1.000000     40.717241    -73.953459
# 75%       16.000000      5.000000      1.000000     40.759123    -73.907733
# max       20.000000      6.000000      1.000000     40.889185    -73.755383
#
#                 fog      ...          pressurei          rain         tempi  \
# count  42649.000000      ...       42649.000000  42649.000000  42649.000000
# mean       0.009824      ...          29.971096      0.224741     63.103780
# std        0.098631      ...           0.137942      0.417417      8.455597
# min        0.000000      ...          29.550000      0.000000     46.900000
# 25%        0.000000      ...          29.890000      0.000000     57.000000
# 50%        0.000000      ...          29.960000      0.000000     61.000000
# 75%        0.000000      ...          30.060000      0.000000     69.100000
# max        1.000000      ...          30.320000      1.000000     86.000000
#
#               wspdi   meanprecipi  meanpressurei     meantempi     meanwspdi  \
# count  42649.000000  42649.000000   42649.000000  42649.000000  42649.000000
# mean       6.927872      0.004618      29.971096     63.103780      6.927872
# std        4.510178      0.016344       0.131158      6.939011      3.179832
# min        0.000000      0.000000      29.590000     49.400000      0.000000
# 25%        4.600000      0.000000      29.913333     58.283333      4.816667
# 50%        6.900000      0.000000      29.958000     60.950000      6.166667
# 75%        9.200000      0.000000      30.060000     67.466667      8.850000
# max       23.000000      0.157500      30.293333     79.800000     17.083333
#
#         weather_lat   weather_lon
# count  42649.000000  42649.000000
# mean      40.728555    -73.938693
# std        0.065420      0.059582
# min       40.600204    -74.014870
# 25%       40.688591    -73.985130
# 50%       40.720570    -73.949150
# 75%       40.755226    -73.912033
# max       40.862064    -73.694176
#
# [8 rows x 21 columns]

# %%
print("Data Acquired between {0} and {1} in NYC".format(pd.datetime.strftime(df.datetime.min(), "%Y/%m/%d"),
                                                 pd.datetime.strftime(df.datetime.max(), "%Y/%m/%d")))
# Out:
# Data Acquired between 2011/05/01 and 2011/05/31 in NYC

# %%
nyc_map = folium.Map(location=(df.latitude[0], df.longitude[0]))

for unit in df[['UNIT', 'latitude', 'longitude', 'station']].drop_duplicates().iterrows():
    n, unit = unit
    nyc_map.circle_marker((unit.latitude, unit.longitude), popup=unit.station, radius = 200, line_color='#3186cc',
                  fill_color='blue', fill_opacity=1)
    
for unit in df[['weather_lat', 'weather_lon']].drop_duplicates().iterrows():
    n, unit = unit
    nyc_map.circle_marker((unit.weather_lat, unit.weather_lon), popup="Weather Station", radius = 200, line_color='red',
                  fill_color='red', fill_opacity=1)


# To enable nbviewer leaflet map visualization an iframe html tag was constructed following
# http://nbviewer.ipython.org/gist/bburky/7763555/folium-ipython.ipynb
#nyc_map
nyc_map._build_map()
HTML('<iframe srcdoc="{srcdoc}" style="width: 100%; height: 510px; border: none"></iframe>'.format(srcdoc=nyc_map.HTML.replace('"', '&quot;')))
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.7.3/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;http://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_4e55dc5bae2c43cba1aebe44b3e4c929&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_4e55dc5bae2c43cba1aebe44b3e4c929', {
#                                        center:[40.689945, -73.872564],
#                                        zoom: 10,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#
#
#       var circle_1 = L.circle([40.689945, -73.872564], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_1.bindPopup(&quot;CYPRESS HILLS&quot;);
#       map.addLayer(circle_1)
#
#       var circle_2 = L.circle([40.69132, -73.867135], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_2.bindPopup(&quot;ELDERTS LANE&quot;);
#       map.addLayer(circle_2)
#
#       var circle_3 = L.circle([40.692304, -73.860151], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_3.bindPopup(&quot;FOREST PARKWAY&quot;);
#       map.addLayer(circle_3)
#
#       var circle_4 = L.circle([40.693866, -73.851568], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_4.bindPopup(&quot;WOODHAVEN BLVD&quot;);
#       map.addLayer(circle_4)
#
#       var circle_5 = L.circle([40.695184, -73.844326], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_5.bindPopup(&quot;104 ST&quot;);
#       map.addLayer(circle_5)
#
#       var circle_6 = L.circle([40.697405, -73.836354], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_6.bindPopup(&quot;111 ST&quot;);
#       map.addLayer(circle_6)
#
#       var circle_7 = L.circle([40.700536, -73.828382], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_7.bindPopup(&quot;121 ST&quot;);
#       map.addLayer(circle_7)
#
#       var circle_8 = L.circle([40.757303, -73.989787], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_8.bindPopup(&quot;42 ST-PA BUS TE&quot;);
#       map.addLayer(circle_8)
#
#       var circle_9 = L.circle([40.752247, -73.993456], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_9.bindPopup(&quot;34 ST-PENN STA&quot;);
#       map.addLayer(circle_9)
#
#       var circle_10 = L.circle([40.752247, -73.993456], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_10.bindPopup(&quot;34 ST-PENN STA&quot;);
#       map.addLayer(circle_10)
#
#       var circle_11 = L.circle([40.75753, -73.969102], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_11.bindPopup(&quot;LEXINGTON-53 ST&quot;);
#       map.addLayer(circle_11)
#
#       var circle_12 = L.circle([40.75753, -73.969102], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_12.bindPopup(&quot;LEXINGTON-53 ST&quot;);
#       map.addLayer(circle_12)
#
#       var circle_13 = L.circle([40.746655, -73.891361], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_13.bindPopup(&quot;ROOSEVELT AVE&quot;);
#       map.addLayer(circle_13)
#
#       var circle_14 = L.circle([40.712622, -73.783815], 200, {
#                             color: '#3186cc',
#                             fillColor: 'blue',
#                             fillOpacity: 1
#                             });
#       circle_14.bindPopup(&quot;JAMAICA-179 ST&quot;);
#       map.addLayer(circle_14)
#
#       var circle_15 = L.circle([40.758652, -

# %% [markdown]
# ## Station Neighbourhood

# %%
nybb = geopandas.read_file('./improved-dataset/nybb_4326.geojson')
nybb.info()
nybb.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 5 columns):
# BoroCode      5 non-null int64
# BoroName      5 non-null object
# Shape_Area    5 non-null float64
# Shape_Leng    5 non-null float64
# geometry      5 non-null object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 240.0+ bytes
#    BoroCode       BoroName    Shape_Area     Shape_Leng  \
# 0         5  Staten Island  1.623847e+09  330454.175930
# 1         3       Brooklyn  1.937810e+09  741227.337073
# 2         4         Queens  3.045079e+09  896875.396450
# 3         1      Manhattan  6.364308e+08  358400.912836
# 4         2          Bronx  1.186822e+09  464475.145651
#
#                                             geometry
# 0  (POLYGON ((-74.05050806403247 40.5664220341608...
# 1  (POLYGON ((-73.8670614947212 40.58208797679341...
# 2  (POLYGON ((-73.83668274106708 40.5949466970158...
# 3  (POLYGON ((-74.01092841268033 40.6844914725429...
# 4  (POLYGON ((-73.89680883223775 40.7958084451597...

# %%
nybb.plot();

# %%
stations = df[['station', 'latitude', 'longitude']].drop_duplicates()
stations = stations.groupby('station').agg({'latitude':np.mean, 'longitude':np.mean}).reset_index(level=0)
stations.columns = ['station', 'mean_lat', 'mean_lon']
stations.head()
# Out:
#          station   mean_lat   mean_lon
# 0          1 AVE  40.730901 -73.981719
# 1  103 ST-CORONA  40.749858 -73.862672
# 2         104 ST  40.695184 -73.844326
# 3         110 ST  40.795066 -73.944297
# 4     110 ST-CPN  40.799110 -73.951807

# %%
coords = geopandas.GeoSeries([Point(lon, lat) for lat, lon in zip(stations.mean_lat, stations.mean_lon)])
stations = geopandas.GeoDataFrame(stations, geometry=coords)

# %%
def neighborhood(point):
    for i, nb in nybb.iterrows():
        if point.within(nb['geometry']):
            return nb['BoroName']

# %%
stations['neighbourhood'] = stations.geometry.apply(neighborhood)
stations.head()
# Out:
#          station   mean_lat   mean_lon                              geometry  \
# 0          1 AVE  40.730901 -73.981719          POINT (-73.981719 40.730901)
# 1  103 ST-CORONA  40.749858 -73.862672          POINT (-73.862672 40.749858)
# 2         104 ST  40.695184 -73.844326  POINT (-73.844326 40.69518400000001)
# 3         110 ST  40.795066 -73.944297  POINT (-73.94429699999998 40.795066)
# 4     110 ST-CPN  40.799110 -73.951807   POINT (-73.95180699999997 40.79911)
#
#   neighbourhood
# 0     Manhattan
# 1        Queens
# 2        Queens
# 3     Manhattan
# 4     Manhattan

# %%
df = geopandas.GeoDataFrame(pd.merge(df, stations, how='left', on='station'))

# %%
df[['neighbourhood', 'station']].drop_duplicates().groupby('neighbourhood').count()
# Out:
#                station
# neighbourhood
# Bronx               23
# Brooklyn            77
# Manhattan           58
# Queens              48
# Staten Island        1

# %%
df.datetime.head()
# Out:
# 0   2011-05-01 00:00:00
# 1   2011-05-01 04:00:00
# 2   2011-05-01 12:00:00
# 3   2011-05-01 16:00:00
# 4   2011-05-01 20:00:00
# Name: datetime, dtype: datetime64[ns]

# %%
sns.boxplot(df.ENTRIESn_hourly, df.hour, widths=4*df.hour.value_counts()/df.hour.value_counts().sum());

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# %load_ext rmagic

# %%
# %%R
# library(ggplot2);
# library(ggmap);
#
# nyc <- get_map(location = c(-73.95, 40.73), zoom=11);
# Out:
# Map from URL : http://maps.googleapis.com/maps/api/staticmap?center=40.73,-73.95&zoom=11&size=%20640x640&scale=%202&maptype=terrain&sensor=false
# Google Maps API Terms of Service : http://developers.google.com/maps/terms

# %%
# %%R -i df
#
# ggmap(nyc, extent="device", legend="topleft")+
#     geom_point(aes(mean_lon, mean_lat, color=neighbourhood), data=df);

# %% [markdown]
# #### Subway Peak Hours
# With the exception of the period from 20:00 to 00:00, subway usage is higher on weekdays. <br>
# Mornings from 08:00 to 12:00 and the period from 16:00 to 20:00 show peak usage.

# %%
sns.factorplot('hour', 'ENTRIESn_hourly', data=df, hue='weekday');

# %% [markdown]
# #### Neighbourhood Usage Patterns
# Manhattan shows a higher average usage on most hours. It also shows a significantly higher usage from 20:00 to 04:00, which indicates it might have a vibrant night life.

# %%
sns.factorplot('hour', 'ENTRIESn_hourly', data=df, hue="neighbourhood", col='weekday');

# %%
sns.factorplot('hour', 'ENTRIESn_hourly', data=df, hue='weekday', col="neighbourhood");

# %%
d = df.groupby(['UNIT', 'hour', 'neighbourhood']).mean().reset_index()

# %%
# %%R -i d
#
# ggmap(nyc, extent="device") +
#         geom_point(aes(mean_lon, mean_lat, colour=neighbourhood, size=ENTRIESn_hourly), data=d) +
#         facet_wrap(~hour)

# %% [markdown]
# # Short Questions

# %% [markdown]
# ### Section 1. Statistical Test

# %% [markdown]
# **Question**

# %% [markdown]
# Which Statistical test did you use to analyse the NYC subway data? Did you use a one-tail or a two-tail P value?

# %% [markdown]
# *Answer* <br>

# %% [markdown]
# I used the Mann-Whitney test, a non-parametric test, as the ENTRIESn_hourly variable is not normally distributed. I used a two-sided test, to evaluate if the hourly entries on rainy days and non-rainy days present distributions with significantly different ranks, that is, if these distributions are significantly different.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

sns.boxplot(df.ENTRIESn_hourly, groupby=df.rain, ax=ax1)
sns.boxplot(df.ENTRIESn_hourly, groupby=df.rain, ax=ax2)
ax2.set_ylim(0, 2600)
ax2.set_title('Zoomed In')

fig.tight_layout()

# %%
import scipy.stats

with_rain = df[df.rain == 1].ENTRIESn_hourly
without_rain = df[df.rain == 0].ENTRIESn_hourly

U, p = scipy.stats.mannwhitneyu(with_rain, without_rain)

print('The Mann-Whitney statistic is: {0}, p-value {1}'.format(U, 2*p))
# Out:
# The Mann-Whitney statistic is: 153635120.5, p-value 5.48213914249e-06

# %% [markdown]
# The Mann-Whitney statistic two-sided p-value is lower than 0.05, therefore,  we reject the hypothesis that there is no difference between the ranks of the rainy and non rainy days hourly Entries distributions, with a confidence of 95%.

# %% [markdown]
# **Question**

# %% [markdown]
# Why is this statistical test appropriate or applicable to the dataset?

# %% [markdown]
# *Answer* <br>

# %% [markdown]
# The ENTRIESn_hourly variable is not normally distributed. Because of that, a Welch's T-Test could not be used, as it assumes normally distributed variables. <br>
# The Mann-Whitney test is a nonparametric test and does not assume normal data, and is, therefore more appropriate.

# %%
g = sns.FacetGrid(df, hue='rain', col='rain')
g.map(sns.kdeplot,'ENTRIESn_hourly', shade=True)
g.fig.suptitle('Hourly Entries Prob Dens')
g.fig.tight_layout()

# %% [markdown]
# **Question**

# %% [markdown]
# What results did you get from this statistical test? These should include the numerical values: p-values, as well as the means for each of the two samples under test.

# %% [markdown]
# *Answer* <br>

# %%
print('Rainy Days mean hourly Entries: {}'.format(with_rain.mean()))
print('Non-Rainy Days mean hourly Entries: {}'.format(without_rain.mean()))
print('')
print('Rainy Days median hourly Entries: {}'.format(with_rain.median()))
print('Non-Rainy Days median hourly Entries: {}'.format(without_rain.median()))
print('')
print('Mann-Whitney Statistic: {}'.format(U))
print('Two-Sided p-value: {}'.format(2*p))
print('')
# Out:
# Rainy Days mean hourly Entries: 2028.19603547
# Non-Rainy Days mean hourly Entries: 1845.53943866
#
# Rainy Days median hourly Entries: 939.0
# Non-Rainy Days median hourly Entries: 893.0
#
# Mann-Whitney Statistic: 153635120.5
# Two-Sided p-value: 5.48213914249e-06

# %% [markdown]
# **Question**

# %% [markdown]
# What is the significance of these results?

# %% [markdown]
# *Answer* <br>

# %% [markdown]
# These results lead us to reject the null-hypothesis that these distributions have equal medians, with a confidence of 95% (this confidence setting was chosen for this test, considering a p-value threshold of 0.05). <br>
# As the one-sided test p-value can be shown as well to be bellow our 0.05 threshold, we conclude that people are more likely to take the subway on rainy days.

# %% [markdown]
# ### Section 2. Linear Regression

# %% [markdown]
# What approach did you use to compute the coefficients theta and produce prediction in your regression model?
#
# - Gradient descent
# - OLS using Statsmodels
# - Or something different

# %% [markdown]
# *Answer* <br>

# %% [markdown]
# I used OLS (statsmodels).

# %%
import statsmodels.formula.api as sm

# %%
mod = sm.ols('ENTRIESn_hourly ~ C(UNIT) + C(hour) + C(rain) + C(day_week)', df)
reg = mod.fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        ENTRIESn_hourly   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.541
# Method:                 Least Squares   F-statistic:                     201.5
# Date:                Tue, 13 Jan 2015   Prob (F-statistic):               0.00
# Time:                        21:59:56   Log-Likelihood:            -3.8455e+05
# No. Observations:               42649   AIC:                         7.696e+05
# Df Residuals:                   42397   BIC:                         7.718e+05
# Df Model:                         251
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept         -323.1545    157.253     -2.055      0.040      -631.374   -14.935
# C(UNIT)[T.R004]    366.8314    215.980      1.698      0.089       -56.495   790.157
# C(UNIT)[T.R005]    357.5026    216.902      1.648      0.099       -67.630   782.635
# C(UNIT)[T.R006]    528.4320    214.517      2.463      0.014       107.974   948.890
# C(UNIT)[T.R007]    165.6400    217.530      0.761      0.446      -260.723   592.003
# C(UNIT)[T.R008]    167.1073    217.849      0.767      0.443      -259.881   594.095
# C(UNIT)[T.R009]    165.9549    215.981      0.768      0.442      -257.372   589.282
# C(UNIT)[T.R011]   7238.6007    213.385     33.923      0.000      6820.362  7656.840
# C(UNIT)[T.R012]   8591.1159    212.840     40.364      0.000      8173.946  9008.286
# C(UNIT)[T.R013]   2489.5568    212.840     11.697      0.000      2072.387  2906.727
# C(UNIT)[T.R016]    665.3068    213.385      3.118      0.002       247.068  1083.546
# C(UNIT)[T.R017]   4104.5514    212.840     19.285      0.000      3687.382  4521.721
# C(UNIT)[T.R018]   7689.8219    213.111     36.084      0.000      7272.120  8107.524
# C(UNIT)[T.R019]   3158.4439    212.840     14.840      0.000      2741.274  3575.614
# C(UNIT)[T.R020]   6280.6482    212.840     29.509      0.000      5863.478  6697.818
# C(UNIT)[T.R021]   4590.3445    213.385     21.512      0.000      4172.105  5008.584
# C(UNIT)[T.R022]   9425.0407    212.840     44.282      0.000      9007.871  9842.210
# C(UNIT)[T.R023]   6060.2181    212.840     28.473      0.000      5643.048  6477.388
# C(UNIT)[T.R024]   3120.4206    213.111     14.642      0.000      2702.718  3538.123
# C(UNIT)[T.R025]   5255.3364    212.840     24.692      0.000      4838.167  5672.506
# C(UNIT)[T.R027]   2874.6536    212.840     13.506      0.000      2457.484  3291.823
# C(UNIT)[T.R029]   7136.6267    212.840     33.531      0.000      6719.457  7553.796
# C(UNIT)[T.R030]   3006.8202    212.840     14.127      0.000      2589.650  3423.990
# C(UNIT)[T.R031]   4258.5890    212.840     20.008      0.000      3841.419  4675.759
# C(UNIT)[T.R032]   4352.8939    213.111     20.425      0.000      3935.192  4770.596
# C(UNIT)[T.R033]   8141.5998    212.840     38.252      0.000      7724.430  8558.770
# C(UNIT)[T.R034]   1027.3035    217.531      4.723      0.000       600.939  1453.668
# C(UNIT)[T.R035]   2703.6116    213.385     12.670      0.000      2285.373  3121.850
# C(UNIT)[T.R036]    635.9997    215.383      2.953      0.003       213.845  1058.154
# C(UNIT)[T.R037]    758.0799    213.663      3.548      0.000       339.296  1176.864
# C(UNIT)[T.R038]    103.1032    215.982      0.477      0.633      -320.227   526.433
# C(UNIT)[T.R039]    632.4092    218.830      2.890      0.004       203.498  1061.321
# C(UNIT)[T.R040]   1158.5666    213.385      5.429      0.000       740.327  1576.806
# C(UNIT)[T.R041]   3006.6321    212.840     14.126      0.000      2589.462  3423.802
# C(UNIT)[T.R042]    489.9394    214.510      2.284      0.022        69.496   910.383
# C(UNIT)[T.R043]   2793.7665    212.840     13.126      0.000      2376.597  3210.936
# C(UNIT)[T.R044]   4585.1751    212.840     21.543      0.000      4168.005  5002.345
# C(UNIT)[T.R046]   8251.6267    212.840     38.769      0.000      7834.457  8668.796
# C(UNIT)[T.R049]   2679.4385    212.840     12.589      0.000      2262.269  3096.608
# C(UNIT)[T.R050]   3933.6988    213.387     18.435      0.000      3515.456  4351.942
# C(UNIT)[T.R051]   5041.1804    212.840     23.685      0.000      4624.011  5458.350
# C(UNIT)[T.R052]   1108.0985    216.900      5.109      0.000       682.969  1533.228
# C(UNIT)[T.R053]   3084.8072    213.385     14.457      0.000      2666.568  3503.046
# C(UNIT)[T.R054]   1366.9186    213.385      6.406      0.000       948.680  1785.157
# C(UNIT)[T.R055]   8249.9546    212.840     38.761      0.000      7832.785  8667.124
# C(UNIT)[T.R056]   1351.6659    213.385      6.334      0.000       933.427  1769.905
# C(UNIT)[T.R057]   4789.5675    212.840     22.503      0.000      4372.398  5206.737
# C(UNIT)[T.R058]    548.4708    213.111      2.574      0.010       130.768   966.173
# C(UNIT)[T.R059]   1090.5961    215.385      5.063      0.000       668.438  1512.754
# C(UNIT)[T.R060]    692.8749    214.509      3.230      0.001       272.432  1113.318
# C(UNIT)[T.R061]    487.6886    218.499      2.232      0.026        59.426   915.951
# C(UNIT)[T.R062]   2643.4277    212.840     12.420      0.000      2226.258  3060.598
# C(UNIT)[T.R063]   1033.8839    218.172      4.739      0.000       606.263  1461.505
# C(UNIT)[T.R064]    743.8366    215.683      3.449      0.001       321.094  1166.579
# C(UNIT)[T.R065]    735.3242    216.901      3.390      0.001       310.194  1160.454
# C(UNIT)[T.R066]    127.7517    217.530      0.587      0.557      -298.610   554.114
# C(UNIT)[T.R067]    755.7233    218.498      3.459      0.001       327.463  1183.984
# C(UNIT)[T.R068]    345.3845    218.499      1.581      0.114       -82.878   773.647
# C(UNIT)[T.R069]    841.1125    216.591      3.883      0.000       416.590  1265.635
# C(UNIT)[T.R070]   1694.4062    212.840      7.961      0.000      1277.236  2111.576
# C(UNIT)[T.R080]   3518.7342    212.840     16.532      0.000      3101.564  3935.904
# C(UNIT)[T.R081]   3470.9927    213.389     16.266      0.000      3052.747  3889.239
# C(UNIT)[T.R082]   1409.0992    213.385      6.604      0.000       990.860  1827.338
# C(UNIT)[T.R083]   3033.1428    212.840     14.251      0.000      2615.973  3450.313
# C(UNIT)[T.R084]   9937.4170    212.840     46.690      0.000      9520.247  1.04e+04
# C(UNIT)[T.R085]   2517.8346    213.387     11.799      0.000      2099.592  2936.077
# C(UNIT)[T.R086]   2506.7342    212.840     11.778      0.000      2089.564  2923.904
# C(UNIT)[T.R087]   1134.1297    213.941      5.301      0.000       714.800  1553.459
# C(UNIT)[T.R089]    419.0948    213.385      1.964      0.050         0.856   837.334
# C(UNIT)[T.R090]    320.8662    218.500      1.468      0.142      -107.399   749.131
# C(UNIT)[T.R091]   1032.6284    217.532      4.747      0.000       606.262  1458.995
# C(UNIT)[T.R092]   1914.2569    215.684      8.875      0.000      1491.512  2337.001
# C(UNIT)[T.R093]   1945.1020    216.288      8.993      0.000      1521.174  2369.030
# C(UNIT)[T.R094]   1684.4946    213.386      7.894      0.000      1266.255  2102.734
# C(UNIT)[T.R095]   2092.3408    214.225      9.767      0.000      1672.455  2512.227
# C(UNIT)[T.R096]   2277.4549    213.111     10.687      0.000      1859.753  2695.156
# C(UNIT)[T.R097]   2898.8597    213.111     13.603      0.000      2481.158  3316.561
# C(UNIT)[T.R098]   1741.2933    212.840      8.181      0.000      1324.124  2158.463
# C(UNIT)[T.R099]   2298.3202    212.840     10.798      0.000      1881.150  2715.490
# C(UNIT)[T.R100]    479.3796    213.945      2.241      0.025        60.043   898.716
# C(UNIT)[T.R101]   2732.7127    212.840     12.839      0.000      2315.543  3149.883
# C(UNIT)[T.R102]   3621.5514    212.840     17.015      0.000      3204.382  4038.721
# C(UNIT)[T.R103]   1314.1316    216.903      6.059      0.000       888.997  1739.266
# C(UNIT)[T.R104]   1273.7338    213.385      5.969      0.000       855.495  1691.973
# C(UNIT)[T.R105]   3271.2503    212.840     15.370      0.000      2854.081  3688.420
# C(UNIT)[T.R106]    982.7346    218.498      4.498      0.000       554.473  1410.996
# C(UNIT)[T.R107]    388.0063    218.829      1.773      0.076       -40.902   816.915
# C(UNIT)[T.R108]   5160.4170    212.840     24.246      0.000      4743.247  5577.587
# C(UNIT)[T.R111]   3157.5407    212.840     14.835      0.000      2740.371  3574.710
# C(UNIT)[T.R112]   1619.1414    213.111      7.598      0.000      1201.440  2036.843
# C(UNIT)[T.R114]    834.2706    213.113      3.915      0.000       416.565  1251.976
# C(UNIT)[T.R115]   1205.9331    212.840      5.666      0.000       788.763  1623.103
# C(UNIT)[T.R116]   3136.6858    212.840     14.737      0.000      2719.516  3553.856
# C(UNIT)[T.R117]    794.7690    218.172      3.643      0.000       367.147  1222.391
# C(UNIT)[T.R119]   1784.8164    214.798      8.309      0.000      1363.809  2205.824
# C(UNIT)[T.R120]   1444.3771    216.285      6.678      0.000      1020.454  1868.300
# C(UNIT)[T.R121]   1393.7177    215.680      6.462      0.000       970.980  1816.456
# C(UNIT)[T.R122]   2510.6275    214.229     11.719      0.000      2090.734  2930.520
# C(UNIT)[T.R123]   1558.3358    214.510      7.265      0.000      1137.892  1978.780
# C(UNIT)[T.R124]    572.7720    217.214      2.637      0.008       147.029   998.515
# C(UNIT)[T.R126]   1798.5944    212.840      8.450      0.000      1381.425  2215.764
# C(UNIT)[T.R127]   4739.3041    212.840     22.267      0.000      4322.134  5156.474
# C(UNIT)[T.R137]   2395.8632    212.840     11.257      0.000      1978.693  2813.033
# C(UNIT)[T.R139]   2472.8595    213.111     11.604      0.000      2055.158  2890.561
# C(UNIT)[T.R163]   3275.0407    212.840     15.387      0.000      2857.871  3692.210
# C(UNIT)[T.R172]   1841.0783    212.840      8.650      0.000      1423.908  2258.248
# C(UNIT)[T.R179]   6721.8525    212.840     31.582      0.000      6304.683  7139.022
# C(UNIT)[T.R181]   1699.3880    214.798      7.912      0.000      1278.380  2120.395
# C(UNIT)[T.R183]    673.2711    218.830      3.077      0.002       244.359  1102.183
# C(UNIT)[T.R184]    916.4183    217.530      4.213      0.000       490.056  1342.781
# C(UNIT)[T.R186]   1020.7162    214.224      4.765      0.000       600.833  1440.600
# C(UNIT)[T.R188]   2274.5966    213.111     10.673      0.000      1856.895  2692.299
# C(UNIT)[T.R189]   1332.6950    215.383      6.188      0.000       910.541  1754.849
# C(UNIT)[T.R194]   1938.5756    214.800      9.025      0.000      1517.564  2359.587
# C(UNIT)[T.R196]   1273.7355    213.662      5.961      0.000       854.954  1692.517
# C(UNIT)[T.R198]   2059.2100    213.385      9.650      0.000      1640.971  2477.449
# C(UNIT)[T.R199]    659.5561    214.799      3.071      0.002       238.545  1080.567
# C(UNIT)[T.R200]   1002.0616    213.943      4.684      0.000       582.729  1421.394
# C(UNIT)[T.R202]   2182.2709    213.388     10.227      0.000      1764.025  2600.516
# C(UNIT)[T.R203]   1706.1664    215.981      7.900      0.000      1282.838  2129.494
# C(UNIT)[T.R204]   1402.5783    212.840      6.590      0.000       985.408  1819.748
# C(UNIT)[T.R205]   1462.7882    213.943      6.837      0.000      1043.455  1882.121
# C(UNIT)[T.R207]   1952.0170    213.111      9.160      0.000      1534.315  2369.719
# C(UNIT)[T.R208]   2465.7496    213.941     11.525      0.000      2046.420  2885.079
# C(UNIT)[T.R209]    714.2759    218.172      3.274      0.001       286.655  1141.897
# C(UNIT)[T.R210]    474.6159    215.383      2.204      0.028        52.461   896.771
# C(UNIT)[T.R211]   2360.0084    212.840     11.088      0.000      1942.839  2777.178
# C(UNIT)[T.R212]   1639.8162    213.111      7.695      0.000      1222.114  2057.518
# C(UNIT)[T.R213]   1099.5495    215.089      5.112      0.000       677.971  1521.129
# C(UNIT)[T.R214]    586.8967    218.498      2.686      0.007       158.636  1015.157
# C(UNIT)[T.R215]   1548.2619    213.387      7.256      0.000      1130.020  1966.504
# C(UNIT)[T.R216]    719.1649    213.385      3.370      0.001       300.926  1137.404
# C(UNIT)[T.R217]    924.9004    218.172      4.239      0.000       497.280  1352.521
# C(UNIT)[T.R218]   1942.1071    213.111      9.113      0.000      1524.405  2359.809
# C(UNIT)[T.R219]   1222.5942    213.387      5.729      0.000       804.351  1640.837
# C(UNIT)[T.R220]   1434.7342    212.840      6.741      0.000      1017.564  1851.904
# C(UNIT)[T.R221]   1330.4953    218.499      6.089      0.000       902.233  1758.757
# C(UNIT)[T.R223]   2081.4008    213.111      9.767      0.000      1663.699  2499.102
# C(UNIT)[T.R224]    674.2709    215.680      3.126      0.002       251.534  1097.008
# C(UNIT)[T.R225]    526.0583    214.226      2.456      0.014       106.171   945.945
# C(UNIT)[T.R226]    653.9168    217.529      3.006      0.003       227.555  1080.279
# C(UNIT)[T.R227]   1053.9976    212.840      4.952      0.000       636.828  1471.167
# C(UNIT)[T.R228]   1062.4364    217.854      4.877      0.000       635.437  1489.435
# C(UNIT)[T.R229]    502.4044    217.213      2.313      0.021        76.662   928.147
# C(UNIT)[T.R230]    460.6234    215.980      2.133      0.033        37.298   883.949
# C(UNIT)[T.R231]    918.7778    214.224      4.289      0.000       498.894  1338.662
# C(UNIT)[T.R232]    956.3816    216.900      4.409      0.000       531.254  1381.509
# C(UNIT)[T.R233]   1022.3931    219.163      4.665      0.000       592.829  1451.957
# C(UNIT)[T.R234]    230.9138    218.172      1.058      0.290      -196.708   658.536
# C(UNIT)[T.R235]   2526.5735    213.111     11.856      0.000      2108.871  2944.276
# C(UNIT)[T.R236]   1478.2480    213.942      6.910      0.000      1058.918  1897.578
# C(UNIT)[T.R237]    582.9415    217.850      2.676      0.007       155.950  1009.933
# C(UNIT)[T.R238]   2064.2530    213.111      9.686      0.000      1646.551  2481.955
# C(UNIT)[T.R239]    851.1589    212.840      3.999      0.000       433.989  1268.329
# C(UNIT)[T.R240]   2610.8167    213.662     12.219      0.000      2192.034  3029.599
# C(UNIT)[T.R242]    492.2615    215.090      2.289      0.022        70.681   913.842
# C(UNIT)[T.R243]   1321.0557    216.593      6.099      0.000       896.530  1745.581
# C(UNIT)[T.R244]   1560.5607    216.600      7.205      0.000      1136.020  1985.102
# C(UNIT)[T.R246]    605.3583    217.849      2.779      0.005       178.369  1032.347
# C(UNIT)[T.R247]     57.4537    219.841      0.261      0.794      -373.438   488.346
# C(UNIT)[T.R248]   3055.1892    213.111     14.336      0.000      2637.487  3472.891
# C(UNIT)[T.R249]   1306.5294    214.509      6.091      0.000       886.087  1726.971
# C(UNIT)[T.R250]    918.4076    215.089      4.270      0.000       496.828  1339.987
# C(UNIT)[T.R251]   1226.0236    213.662      5.738      0.000       807.242  1644.805
# C(UNIT)[T.R252]    910.2762    213.385      4.266      0.000       492.037  1328.515
# C(UNIT)[T.R253]    689.9064    216.914      3.181      0.001       264.750  1115.063
# C(UNIT)[T.R254]   2551.7247    213.113     11.974      0.000      2134.019  2969.430
# C(UNIT)[T.R255]    723.2217    213.942      3.380      0.001       303.891  1142.552
# C(UNIT)[T.R256]   1016.5065    213.387      4.764      0.000       598.264  1434.749
# C(UNIT)[T.R257]   1838.3310    212.840      8.637      0.000      1421.161  2255.501
# C(UNIT)[T.R258]   1476.6738    213.663      6.911      0.000      1057.890  1895.458
# C(UNIT)[T.R259]    876.7375    214.510      4.087      0.000       456.293  1297.182
# C(UNIT)[T.R260]   1037.0988    222.333      4.665      0.000       601.321  1472.876
# C(UNIT)[T.R261]   1508.6721    215.384      7.005      0.000      1086.516  1930.828
# C(UNIT)[T.R262]    366.4576    219.840      1.667      0.096       -64.433   797.349
# C(UNIT)[T.R263]     76.0311    215.091      0.353      0.724      -345.552   497.614
# C(UNIT)[T.R264]    423.8067    213.113      1.989      0.047         6.101   841.512
# C(UNIT)[T.R265]    790.8388    217.213      3.641      0.000       365.096  1216.581
# C(UNIT)[T.R266]    863.9218    213.111      4.054      0.000       446.220  1281.624
# C(UNIT)[T.R269]    831.5044    213.387      3.897      0.000       413.262  1249.747
# C(UNIT)[T.R270]    407.5858    217.852      1.871      0.061       -19.409   834.581
# C(UNIT)[T.R271]    292.5136    217.531      1.345      0.179      -133.851   718.878
# C(UNIT)[T.R273]   1292.5353    218.181      5.924      0.000       864.897  1720.174
# C(UNIT)[T.R274]    889.2606    216.906      4.100      0.000       464.121  1314.401
# C(UNIT)[T.R275]    838.0882    215.385      3.891      0.000       415.929  1260.247
# C(UNIT)[T.R276]   1360.8686    212.840      6.394      0.000       943.699  1778.038
# C(UNIT)[T.R277]    340.4699    220.885      1.541      0.123       -92.469   773.409
# C(UNIT)[T.R278]    295.3203    217.214      1.360      0.174      -130.424   721.065
# C(UNIT)[T.R279]    707.3846    214.798      3.293      0.001       286.377  1128.392
# C(UNIT)[T.R280]    569.5322    220.190      2.587      0.010       137.955  1001.109
# C(UNIT)[T.R281]   1225.4651    214.512      5.713      0.000       805.018  1645.912
# C(UNIT)[T.R282]   1530.6285    213.385      7.173      0.000      1112.390  1948.867
# C(UNIT)[T.R284]    718.6729    213.385      3.368      0.001       300.434  1136.912
# C(UNIT)[T.R285]    508.9695    218.501      2.329      0.020        80.704   937.235
# C(UNIT)[T.R287]    456.5415    218.831      2.086      0.037        27.629   885.454
# C(UNIT)[T.R291]   1754.0998    212.840      8.241      0.000      1336.930  2171.270
# C(UNIT)[T.R294]    875.7696    215.384      4.066      0.000       453.613  1297.926
# C(UNIT)[T.R295]    520.8227    229.736      2.267      0.023        70.535   971.110
# C(UNIT)[T.R300]   2163.1643    212.840     10.163      0.000      1745.994  2580.334
# C(UNIT)[T.R303]   1170.5518    214.511      5.457      0.000       750.107  1590.997
# C(UNIT)[T.R304]   1029.7239    213.387      4.826      0.000       611.482  1447.966
# C(UNIT)[T.R307]    237.6778    218.829      1.086      0.277      -191.231   666.586
# C(UNIT)[T.R308]    716.8756    216.590      3.310      0.001       292.354  1141.397
# C(UNIT)[T.R309]    749.7181    216.288      3.466      0.001       325.789  1173.647
# C(UNIT)[T.R310]   1199.1829    217.530      5.513      0.000       772.821  1625.545
# C(UNIT)[T.R311]    315.3568    215.981      1.460      0.144      -107.970   738.684
# C(UNIT)[T.R312]    269.4740    213.662      1.261      0.207      -149.308   688.256
# C(UNIT)[T.R313]    -53.2810    219.161     -0.243      0.808      -482.842   376.279
# C(UNIT)[T.R318]    475.0178    213.942      2.220      0.026        55.688   894.348
# C(UNIT)[T.R319]   1276.8898    214.799      5.945      0.000       855.879  1697.901
# C(UNIT)[T.R321]   1025.7611    212.840      4.819      0.000       608.591  1442.931
# C(UNIT)[T.R322]   1704.8803    214.801      7.937      0.000      1283.866  2125.895
# C(UNIT)[T.R323]   1177.9727    216.900      5.431      0.000       752.843  1603.102
# C(UNIT)[T.R325]    258.8108    215.981      1.198      0.231      -164.517   682.139
# C(UNIT)[T.R330]    908.1707    215.385      4.216      0.000       486.011  1330.330
# C(UNIT)[T.R335]    272.7277    219.501      1.242      0.214      -157.499   702.955
# C(UNIT)[T.R336]    -85.0145    219.500     -0.387      0.699      -515.239   345.210
# C(UNIT)[T.R337]    -29.6119    218.174     -0.136      0.892      -457.238   398.014
# C(UNIT)[T.R338]   -159.1513    216.285     -0.736      0.462      -583.074   264.771
# C(UNIT)[T.R341]    433.1035    213.666      2.027      0.043        14.313   851.894
# C(UNIT)[T.R344]    366.6604    219.502      1.670      0.095       -63.569   796.890
# C(UNIT)[T.R345]    376.3699    215.980      1.743      0.081       -46.955   799.695
# C(UNIT)[T.R346]   1160.8771    216.287      5.367      0.000       736.950  1584.804
# C(UNIT)[T.R348]     30.1105    216.284      0.139      0.889      -393.810   454.031
# C(UNIT)[T.R354]     69.9133    218.499      0.320      0.749      -358.349   498.175
# C(UNIT)[T.R356]   1010.4726    215.685      4.685      0.000       587.725  1433.220
# C(UNIT)[T.R358]    109.6959    218.499      0.502      0.616      -318.566   537.958
# C(UNIT)[T.R370]    383.2858    215.680      1.777      0.076       -39.451   806.022
# C(UNIT)[T.R371]    601.2388    216.900      2.772      0.006       176.110  1026.368
# C(UNIT)[T.R372]    582.9315    217.849      2.676      0.007       155.943  1009.920
# C(UNIT)[T.R373]    532.8264    218.175      2.442      0.015       105.200   960.453
# C(UNIT)[T.R382]    806.3050    215.383      3.744      0.000       384.150  1228.460
# C(UNIT)[T.R424]    231.5307    219.164      1.056      0.291      -198.035   661.096
# C(UNIT)[T.R429]    924.8297    213.662      4.328      0.000       506.048  1343.611
# C(UNIT)[T.R453]   1668.4979    220.195      7.577      0.000      1236.912  2100.084
# C(UNIT)[T.R454]    -12.1327    218.499     -0.056      0.956      -440.396   416.130
# C(UNIT)[T.R455]    -62.3076    218.174     -0.286      0.775      -489.933   365.318
# C(UNIT)[T.R456]    122.1933    215.389      0.567      0.571      -299.973   544.359
# C(UNIT)[T.R459]   -103.7351    263.151     -0.394      0.693      -619.517   412.047
# C(UNIT)[T.R464]   -222.5494    217.849     -1.022      0.307      -649.537   204.438
# C(hour)[T.4]     -1091.1430     32.919    -33.147      0.000     -1155.664 -1026.622
# C(hour)[T.8]      -802.5096     35.006    -22.925      0.000      -871.122  -733.897
# C(hour)[T.12]     1602.8311     32.971     48.614      0.000      1538.208  1667.454
# C(hour)[T.16]      895.2824     33.013     27.119      0.000       830.577   959.988
# C(hour)[T.20]     1821.4825     32.961     55.261      0.000      1756.877  1886.088
# C(rain)[T.1]        39.3795     24.193      1.628      0.104        -8.039    86.798
# C(day_week)[T.1]   362.8238     33.740     10.754      0.000       296.693   428.955
# C(day_week)[T.2]   416.2545     36.725     11.334      0.000       344.273   488.236
# C(day_week)[T.3]   443.9096     36.074     12.306      0.000       373.204   514.615
# C(day_week)[T.4]   396.4815     36.133     10.973      0.000       325.660   467.303
# C(day_week)[T.5]  -511.8524     36.387    -14.067      0.000      -583.171  -440.534
# C(day_week)[T.6]  -839.8920     34.092    -24.636      0.000      -906.713  -773.071
# ==============================================================================
# Omnibus:                    30223.391   Durbin-Watson:                   1.521
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1100755.379
# Skew:                           2.976   Prob(JB):                         0.00
# Kurtosis:                      27.166   Cond. No.                         285.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Question**

# %% [markdown]
# What features did you use in your model? Did you use any dummy variables as part of your features?

# %% [markdown]
# *Answer* <br>

# %% [markdown]
# I used UNIT, hour, rain and day_week (day of the week), all dummy variables.

# %% [markdown]
# **Question**

# %% [markdown]
# Why did you select these features in your model? We are looking for specific reasons that lead you to believe that the selected features will contribute to the predictive power of your model.

# %% [markdown]
# *Answer* <br>

# %% [markdown]
# I selected these variables analysing the previous data exploration step. These variables seemed to contribute a lot to the Entries variations. I also did a bit of testing to check for improvements on $R^{2}$ and AIC.

# %% [markdown]
# **Question**

# %% [markdown]
# What does this $R^{2}$ value mean for the goodness of fit for your regression model? Do you think this linear model is appropriate for this dataset, given this $R^{2}$ value?

# %% [markdown]
# *Answer* <br>

# %% [markdown]
# It means that the selected variables explain 54.4% of the variance of the linear regression model residuals. It would be interesting to test non-linear models and variable selection technics, to try to improve our hourly entries model, in particular the model behaviour under cross-validation.

# %% [markdown]
# ### Section 3. Visualization

# %% [markdown]
# **Question**

# %% [markdown]
# Please include two visualizations that show the relationships between two or more variables in the NYC subway data. You should feel free to implement something that we discussed in class (e.g., scatterplots, line plots, or histograms) or attempt to implement something more advanced if you'd like.
# Remember to add appropriate titles and axes labels to your
# plots. Also please add a short description below each figure commenting on the key insights depicted in the figure.

# %% [markdown]
# One visualization should be two histograms of ENTRIESn_hourly for rainy days and non-rainy days. Remember to increase the number of bins on the histogram (by having larger number of bars, each with smaller width). The default bin width is not sufficient to capture the variability in the two samples.

# %% [markdown]
# *Answer* <br>

# %%
g = sns.FacetGrid(df, col='rain');
ax = g.map(plt.hist, 'ENTRIESn_hourly', normed=True, bins=30);
ax.set_xlabels('Hourly Entries');

# %% [markdown]
# As requested, this graph shows histograms of hourly entries on rainy and non-rainy days.

# %% [markdown]
# **Question**

# %% [markdown]
# One visualization can be more freeform, some suggestions are:
# - Ridership by time-of-day or day-of-week
# - How ridership varies by subway station
# - Which stations have more exits or entries at different times of day

# %% [markdown]
# *Answer* <br>

# %%
sns.factorplot('hour', 'ENTRIESn_hourly', data=df, hue='weekday', col="neighbourhood");

# %% [markdown]
# This graph shows the mean hourly entries of passengers in NYC neighbourhoods, comparing weekdays and weekends. Weekdays see a significantly larger subway usage on all hours with the exception of the 20:00 to 00:00 period. This may reflect a more vibrant nightlife on weekends. We can see as well a very large mean usage on Manhattan in the period from 16:00 to 20:00, reflecting it is a neighbourhood where people are on the streets and on the move till latter hours than in other neighbourhoods.

# %% [markdown]
# *Additional Visualization*

# %% [markdown]
# Effect of Rain on Mean Subway usage patterns

# %%
sns.factorplot('hour', 'ENTRIESn_hourly', data=df, hue='rain', col='neighbourhood');

# %%
for neighbourhood in ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island']:
    with_rain = df[(df.rain == 1) & (df.neighbourhood == neighbourhood)].ENTRIESn_hourly
    without_rain = df[(df.rain == 0) & (df.neighbourhood == neighbourhood)].ENTRIESn_hourly

    U, p = scipy.stats.mannwhitneyu(with_rain, without_rain)

    print('{}'.format(neighbourhood))
    print('The Mann-Whitney statistic is: {0}, p-value {1}'.format(U, p))
    print('')
# Out:
# Bronx
# The Mann-Whitney statistic is: 1587611.5, p-value 0.200893401365
#
# Brooklyn
# The Mann-Whitney statistic is: 19615200.5, p-value 0.000358188424598
#
# Manhattan
# The Mann-Whitney statistic is: 16544996.5, p-value 8.23895481301e-06
#
# Queens
# The Mann-Whitney statistic is: 6494103.0, p-value 0.0995204705884
#
# Staten Island
# The Mann-Whitney statistic is: 2909.5, p-value 0.355192901203

# %% [markdown]
# We can see running individual tests for each neighbourhood that median subway usage on rainy days is significantly higher, with a confidence of 95%, on Manhattan and Brooklyn. From the graph, we can see that this difference is only significant at the neighbourhood's peak hours.

# %% [markdown]
# ### Section 4. Conclusion

# %% [markdown]
# Please address the following questions in detail. Your answers should be 1-2 paragraphs long.

# %% [markdown]
# **Question**

# %% [markdown]
# 1 - From your analysis and interpretation of the data, do more people ride
# the NYC subway when it is raining versus when it is not raining?

# %% [markdown]
# *Answer* <br>

# %% [markdown]
# People use the NYC subway more often when it is raining, though usage patterns vary on each neighbourhood and hour. On some periods, for example from 00:00 to 04:00, rain does not have a significant effect on subway usage.

# %% [markdown]
# **Question**

# %% [markdown]
# 2 -  What analyses lead you to this conclusion?

# %% [markdown]
# *Answer* <br>

# %% [markdown]
# Analysing our Mann-Whitney test results as a one-sided test, we can also reject the hypothesis that the medians of the hourly entries in the NYC subway on rainy and non-rainy days are equal and come to a conclusion that the subway usage on rainy days is larger than on non-rainy days, with a 95% confidence.

# %% [markdown]
# ### Section 5. Reflection

# %% [markdown]
# Please address the following questions in detail. Your answers should be 1-2 paragraphs long.

# %% [markdown]
# **Question**

# %% [markdown]
# Please discuss potential shortcomings of the dataset and the methods
# of your analysis.

# %% [markdown]
# *Answer* <br>

# %% [markdown]
# Our dataset does not have balanced entries and exits.

# %%
df.ENTRIESn_hourly.sum() / float(df.EXITSn_hourly.sum())
# Out:
# 1.3856825332290292

# %% [markdown]
# If each passenger went through a single entry and a single exit turnstile, we would expect net usage to be balanced.
# A non-balanced dataset might be due to a number of reasons:
#
# - Large stations (maybe connecting stations) might be arranged so that passengers may go through multiple entry turnstiles
# - The dataset may have been sampled from a larger dataset in an unbalanced manner.
# - Turnstile sensors may have malfunctioned been misused.

# %% [markdown]
# To evaluate these hypothesis it would be important to analyse how the data was gathered. <br>
# Regarding the methods used, some interesting articles I have [read](http://jakevdp.github.io/blog/2014/03/11/frequentism-and-bayesianism-a-practical-intro/) describe the use of p-values, and frequentist methods in general, prone to misinterpretation. T-Tests commonly are based on assumptions and lead to conclusions that require some attention.

# %% [markdown]
# **Question**

# %% [markdown]
# (Optional) Do you have any other insight about the dataset that you would like to share with us?

# %% [markdown]
# *Answer* <br>
